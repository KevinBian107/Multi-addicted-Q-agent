# %% [markdown]
# # Outputting Figures
# All functions here retrains the agent before plotting, this is why pass in CONFIGS

# %%
# %load_ext autoreload
# %autoreload 2
from src.figures import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
CONFIGS = {
    'alpha': 0.1,
    'gamma': 0.9,
    'epsilon': 0.1,
    'num_trials': 100,
    'num_states': 10,
    'num_actions': 3,
    'initial_dopamine_surge': 1,
    'dopamine_decay_rate': 0.99,
    'reward_states': [0, 9],
    'drug_reward': 1,
    'addicted': True,
    'exploration_strategy': 'epsilon_greedy',
    'if_natural': True,
    'natural_reward_states': [5],
    'natural_reward_boost': 2
}

# %% [markdown]
# # Figure 1 Heatmap of Q-value for Different Startegy Agent and Reward States
# natural reward at 5, drug reward at 0 and 9

# %%
plot_heatmap_for_configs(CONFIGS)

# %% [markdown]
# # Figure 2 Average RPE for Different Search Strategy Q-agent Under Addiction/Non-Addiction

# %%
plot_all_rpe_avg(CONFIGS)

# %% [markdown]
# # Figure 3: Expected Visits When Natural Reward is Presented

# %%
plot_all_expected_visits(CONFIGS)
